# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv('./train.csv')

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
X = np.array(data['x'])

# %%
y = np.array(data['y'])

# %%
import matplotlib.pyplot as plt

# %%
# data['x']

# plt.show(data['x'], data['y'], 'ro')

plt.plot(X, y, 'ro')

# %%
plt.plot(data['x'], data['y'], 'bo')

# %%
from sklearn.linear_model import LinearRegression

# %%
# model = LinearRegression().fit([[1], [1], [2], [2]], [2,3,4,5])

# %%
X
# Out:
# array([2.40000000e+01, 5.00000000e+01, 1.50000000e+01, 3.80000000e+01,
#        8.70000000e+01, 3.60000000e+01, 1.20000000e+01, 8.10000000e+01,
#        2.50000000e+01, 5.00000000e+00, 1.60000000e+01, 1.60000000e+01,
#        2.40000000e+01, 3.90000000e+01, 5.40000000e+01, 6.00000000e+01,
#        2.60000000e+01, 7.30000000e+01, 2.90000000e+01, 3.10000000e+01,
#        6.80000000e+01, 8.70000000e+01, 5.80000000e+01, 5.40000000e+01,
#        8.40000000e+01, 5.80000000e+01, 4.90000000e+01, 2.00000000e+01,
#        9.00000000e+01, 4.80000000e+01, 4.00000000e+00, 2.50000000e+01,
#        4.20000000e+01, 0.00000000e+00, 6.00000000e+01, 9.30000000e+01,
#        3.90000000e+01, 7.00000000e+00, 2.10000000e+01, 6.80000000e+01,
#        8.40000000e+01, 0.00000000e+00, 5.80000000e+01, 1.90000000e+01,
#        3.60000000e+01, 1.90000000e+01, 5.90000000e+01, 5.10000000e+01,
#        1.90000000e+01, 3.30000000e+01, 8.50000000e+01, 4.40000000e+01,
# ...

# %%
X.shape[0]
# Out:
# 700

# %%
X = X.reshape(X.shape[0], 1)

# %%
model = LinearRegression().fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-b09f2fa55f8f> in <module>
# ----> 1 model = LinearRegression().fit(X, y)
#
# ~/opt/anaconda3/envs/basic-linear-regression/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~/opt/anaconda3/envs/basic-linear-regression/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
y = data['y']

# %%
model = LinearRegression.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-5d2f4ca77a22> in <module>
# ----> 1 model = LinearRegression.fit(X, y)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
y.shape
# Out:
# (700,)

# %%
X.shape
# Out:
# (700, 1)

# %%
data['x'].size
# Out:
# 700

# %%
model = LinearRegression.fit(data['x'], data['y'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-234448b95a5f> in <module>
# ----> 1 model = LinearRegression.fit(data['x'], data['y'])
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
X = np.array(data['x']).reshape(data['x'].shape[0],1)

# %%
X.shape
# Out:
# (700, 1)

# %%
y = np.array(data['y']).reshape(data['y'].shape[0], 1)

# %%
y
# Out:
# array([[ 21.54945196],
#        [ 47.46446305],
#        [ 17.21865634],
#        [ 36.58639803],
#        [ 87.28898389],
#        [ 32.46387493],
#        [ 10.78089683],
#        [ 80.7633986 ],
#        [ 24.61215147],
#        [  6.96331907],
#        [ 11.23757338],
#        [ 13.53290206],
#        [ 24.60323899],
#        [ 39.40049976],
#        [ 48.43753838],
#        [ 61.69900319],
#        [ 26.92832418],
#        [ 70.4052055 ],
#        [ 29.34092408],
#        [ 25.30895192],
#        [ 69.02934339],
#        [ 84.99484703],
#        [ 57.04310305],
#        [ 50.5921991 ],
#        [ 83.02772202],
#        [ 57.05752706],
#        [ 47.95883341],
#        [ 24.34226432],
#        [ 94.68488281],
#        [ 48.03970696],
#        [  7.08132338],
#        [ 21.99239907],
#        [ 42.33151664],
#        [  0.32908944],
#        [ 61.92303698],
#        [ 91.17716423],
#        [ 39.45358014],
#        [  5.99606961],
#        [ 22.59015942],
#        [ 61.18044414],
# ...

# %%
y.shape
# Out:
# (700, 1)

# %%
plt.plot(X, y, 'ro')

# %%
model = LinearRegression().fit([[1.23], [2.123123], [3.12312]], [1,2,3])

# %%
x1 = np.array([[1.23], [2.123123], [3.12312]])

# %%
x1.shape
# Out:
# (3, 1)

# %%
model = LinearRegression().fit(x1, [1,2,3])

# %%
x2 = np.array([1,2,3])

# %%
x2.shape
# Out:
# (3,)

# %%
X
# Out:
# [[1.23], [2.123123], [3.12312]]

# %%
model = LinearRegression().fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-b09f2fa55f8f> in <module>
# ----> 1 model = LinearRegression().fit(X, y)
#
# ~/opt/anaconda3/envs/basic-linear-regression/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~/opt/anaconda3/envs/basic-linear-regression/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
X
# Out:
# array([[2.40000000e+01],
#        [5.00000000e+01],
#        [1.50000000e+01],
#        [3.80000000e+01],
#        [8.70000000e+01],
#        [3.60000000e+01],
#        [1.20000000e+01],
#        [8.10000000e+01],
#        [2.50000000e+01],
#        [5.00000000e+00],
#        [1.60000000e+01],
#        [1.60000000e+01],
#        [2.40000000e+01],
#        [3.90000000e+01],
#        [5.40000000e+01],
#        [6.00000000e+01],
#        [2.60000000e+01],
#        [7.30000000e+01],
#        [2.90000000e+01],
#        [3.10000000e+01],
#        [6.80000000e+01],
#        [8.70000000e+01],
#        [5.80000000e+01],
#        [5.40000000e+01],
#        [8.40000000e+01],
#        [5.80000000e+01],
#        [4.90000000e+01],
#        [2.00000000e+01],
#        [9.00000000e+01],
#        [4.80000000e+01],
#        [4.00000000e+00],
#        [2.50000000e+01],
#        [4.20000000e+01],
#        [0.00000000e+00],
#        [6.00000000e+01],
#        [9.30000000e+01],
#        [3.90000000e+01],
# ...
